# %% [markdown]
# <a href="https://colab.research.google.com/github/sanju492/first_project/blob/main/PREPROCESSING_CASESTUDY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##DATA LOADING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data=pd.read_csv("/content/House_Pricing.csv")
housing_data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %% [markdown]
# ##EDA
# ###data overview

# %%
housing_data.head(5)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
housing_data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
housing_data.shape
# Out:
# (21613, 21)

# %%
housing_data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
housing_data.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
#SPLITTING DATA INTO NUMERICAL AND CATEGORICAL
numerical_data=housing_data.select_dtypes(include=['int64','float64'])
numerical_data
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %%
categorical_data=housing_data.select_dtypes('object')
categorical_data
# Out:
#       Date House was Sold Waterfront View No of Times Visited  \
# 0         14 October 2017              No                 NaN
# 1        14 December 2017              No                 NaN
# 2        15 February 2016              No                 NaN
# 3        14 December 2017              No                 NaN
# 4        15 February 2016              No                 NaN
# ...                   ...             ...                 ...
# 21608         14 May 2017              No                 NaN
# 21609    15 February 2016              No                 NaN
# 21610        14 June 2017              No                 NaN
# 21611     15 January 2016              No                 NaN
# 21612     14 October 2017              No                 NaN
#
#       Condition of the House
# 0                       Fair
# 1                       Fair
# 2                       Fair
# 3                  Excellent
# 4                       Fair
# ...                      ...
# ...

# %%
#plotting histogram for numerical data
for i ,col in enumerate(numerical_data):
  plt.figure(figsize=(8,8))
  sns.histplot(data=numerical_data,x=col,kde=True)
  plt.title(col)
  plt.show()

# %%
#plotting  Box plots for numerical features
for i ,col in enumerate(numerical_data):
  plt.figure(figsize=(8,8))
  sns.boxplot(data=numerical_data,y=col)
  plt.title(col)
  plt.show()

# %%
#plotting countplot for categorical data
for col in categorical_data.columns:
    plt.figure(figsize=(8,8))
    sns.countplot(data=housing_data,x=col)
    plt.xticks(rotation=45)
    plt.title(col)
    plt.show()

# %%
corr=numerical_data.corr()
corr
# Out:
#                                                  ID  Sale Price  \
# ID                                         1.000000   -0.016834
# Sale Price                                -0.016834    1.000000
# No of Bedrooms                             0.001286    0.308463
# No of Bathrooms                            0.005186    0.525124
# Flat Area (in Sqft)                       -0.012384    0.702081
# Lot Area (in Sqft)                        -0.132110    0.089616
# No of Floors                               0.018525    0.256941
# Overall Grade                              0.013799    0.580654
# Area of the House from Basement (in Sqft) -0.010738    0.605495
# Basement Area (in Sqft)                   -0.005151    0.323813
# Age of House (in Years)                   -0.021380   -0.054034
# Renovated Year                            -0.016907    0.126436
# Zipcode                                   -0.008269   -0.053198
# Latitude                                  -0.001952    0.306889
# ...

# %% [markdown]
# ##Duplicate Removal

# %%
#removal of dupilcate rows
print("Number of rows before removing duplicates:", housing_data.shape[0])

housing_data.drop_duplicates(inplace=True)

print("Number of rows after removing duplicates:", housing_data.shape[0])
# Out:
# Number of rows before removing duplicates: 21613
# Number of rows after removing duplicates: 21613

# %%
#removal of duplicate columns
housing_data.columns #checking columns
# Out:
# Index(['ID', 'Date House was Sold', 'Sale Price', 'No of Bedrooms',
#        'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
#        'No of Floors', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
#checking for duplicate columns
duplicate_cols=housing_data.T.duplicated()
print(duplicate_cols)
# Out:
# ID                                           False
# Date House was Sold                          False
# Sale Price                                   False
# No of Bedrooms                               False
# No of Bathrooms                              False
# Flat Area (in Sqft)                          False
# Lot Area (in Sqft)                           False
# No of Floors                                 False
# Waterfront View                              False
# No of Times Visited                          False
# Condition of the House                       False
# Overall Grade                                False
# Area of the House from Basement (in Sqft)    False
# Basement Area (in Sqft)                      False
# Age of House (in Years)                      False
# Renovated Year                               False
# Zipcode                                      False
# Latitude                                     False
# ...

# %% [markdown]
# ##Handling Missing Values

# %%
#Identify missing values in each column.
housing_data.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
#sale price is the target variable so we are removing the null rows
housing_data=housing_data.dropna(subset=['Sale Price'])

# %%
from scipy.stats import skew

# %%
skewness =housing_data['No of Bathrooms'].skew
skewness() #checking skew
# Out:
# np.float64(0.511388973184557)

# %%
housing_data.loc[:,'No of Bathrooms'] = housing_data['No of Bathrooms'].fillna(housing_data['No of Bathrooms'].median()) #filling with median

# %%
housing_data.loc[:,'Flat Area (in Sqft)'] = housing_data['Flat Area (in Sqft)'].fillna(housing_data['Area of the House from Basement (in Sqft)'] + housing_data['Basement Area (in Sqft)'])

# %%
housing_data.loc[:,'Area of the House from Basement (in Sqft)']=housing_data['Area of the House from Basement (in Sqft)'].fillna(housing_data['Flat Area (in Sqft)']-housing_data['Lot Area (in Sqft)'])

# %%
housing_data.isnull().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       0
# No of Bedrooms                                   0
# No of Bathrooms                                  0
# Flat Area (in Sqft)                              0
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19485
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        0
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
housing_data.loc[:,'Lot Area (in Sqft)']=housing_data['Lot Area (in Sqft)'].fillna(housing_data['Lot Area after Renovation (in Sqft)'])

# %%
housing_data = housing_data.drop('No of Times Visited', axis=1)

# %%
housing_data = housing_data.dropna(subset=['Zipcode'])

# %%
housing_data = housing_data.drop(['Latitude', 'Longitude'],axis=1)

# %%
housing_data = housing_data.drop(['Lot Area (in Sqft)','Renovated Year'],axis=1)

# %%
housing_data = housing_data.dropna(subset=['Living Area after Renovation (in Sqft)'])

# %%
housing_data=housing_data.drop(['ID','Area of the House from Basement (in Sqft)','Basement Area (in Sqft)'],axis=1)

# %%
housing_data = housing_data.drop('Date House was Sold', axis=1)

# %%
housing_data = housing_data.drop('Flat Area (in Sqft)', axis=1)

# %%
housing_data.isnull().sum()
# Out:
# Sale Price                                0
# No of Bedrooms                            0
# No of Bathrooms                           0
# No of Floors                              0
# Waterfront View                           0
# Condition of the House                    0
# Overall Grade                             0
# Age of House (in Years)                   0
# Zipcode                                   0
# Living Area after Renovation (in Sqft)    0
# Lot Area after Renovation (in Sqft)       0
# dtype: int64

# %%
#handling outliers

# %%
skewness=housing_data['Sale Price'].skew
skewness()
# Out:
# np.float64(4.021333164159053)

# %%
#applying log transformation on sale price as it is the target variable
housing_data['Sale Price']=np.log(housing_data['Sale Price'])

# %%
#handling outlier in no of bathrooom
skewness=housing_data['No of Bedrooms'].skew
skewness()
# Out:
# np.float64(1.97475948795673)

# %%
q1 = np.quantile(housing_data['No of Bedrooms'],0.25)
q3 = np.quantile(housing_data['No of Bedrooms'],0.75)
iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 5.5
# 1.5
# 1.0

# %%
no_of_bedroom_outliers = []
for i in housing_data['No of Bedrooms']:
  if i > upper_bound or i < lower_bound:
    no_of_bedroom_outliers.append(i)
no_of_bedroom_outliers
# Out:
# [1,
#  6,
#  6,
#  6,
#  1,
#  6,
#  1,
#  1,
#  6,
#  6,
#  7,
#  6,
#  1,
#  6,
#  6,
#  6,
#  6,
#  1,
#  0,
#  1,
#  1,
#  7,
#  1,
#  6,
#  6,
#  6,
#  6,
#  7,
#  6,
#  6,
#  6,
#  1,
#  1,
#  6,
#  1,
#  6,
#  6,
#  6,
#  6,
#  6,
#  1,
#  1,
#  8,
#  6,
#  6,
#  6,
#  1,
#  6,
#  6,
#  6,
#  1,
#  1,
#  1,
#  6,
#  1,
#  1,
#  1,
#  6,
#  6,
#  1,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  1,
#  6,
#  6,
#  6,
#  6,
#  6,
#  1,
#  1,
#  1,
#  1,
#  6,
#  1,
#  0,
#  6,
#  1,
#  6,
#  1,
#  1,
#  1,
#  6,
#  1,
#  0,
#  1,
#  6,
#  6,
#  6,
#  1,
#  1,
#  6,
#  6,
#  1,
#  6,
#  7,
#  6,
#  6,
#  6,
#  1,
#  1,
#  1,
#  6,
#  6,
#  1,
#  1,
#  7,
#  8,
#  8,
#  1,
#  9,
#  6,
#  1,
#  6,
#  9,
#  6,
#  6,
#  6,
#  1,
#  1,
#  1,
#  6,
#  6,
#  6,
#  1,
#  6,
#  6,
#  6,
#  7,
#  7,
#  1,
#  7,
#  0,
#  1,
#  6,
#  1,
#  6,
#  6,
#  6,
#  1,
#  6,
#  6,
#  1,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  1,
#  1,
#  1,
#  1,
#  1,
#  6,
# ...

# %%
housing_data['No of Bedrooms']= housing_data['No of Bedrooms'].clip(lower = lower_bound,upper= upper_bound) #clipping data using IQR

# %%
plt.boxplot(housing_data['No of Bedrooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef8c8e7cfb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef8c8e7c7a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef8c8e7cfe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef8d05d6720>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef8cf0c0920>],
#  'means': []}

# %%
#handling oulier in no of bathrooms
skewness=housing_data['No of Bathrooms'].skew
skewness()
# Out:
# np.float64(0.5114969592114391)

# %%
q1 = np.quantile(housing_data['No of Bathrooms'],0.25)
q3 = np.quantile(housing_data['No of Bathrooms'],0.75)
iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 3.625
# 0.625
# 0.75

# %%
no_of_bathroom_outliers = []
for i in housing_data['No of Bathrooms']:
  if i > upper_bound or i < lower_bound:
    no_of_bathroom_outliers.append(i)
no_of_bathroom_outliers
# Out:
# [4.5,
#  4.0,
#  4.0,
#  4.75,
#  5.0,
#  4.25,
#  4.5,
#  4.25,
#  3.75,
#  5.0,
#  4.0,
#  4.0,
#  4.25,
#  4.25,
#  0.0,
#  4.25,
#  4.5,
#  4.5,
#  3.75,
#  4.5,
#  4.0,
#  0.0,
#  4.5,
#  5.25,
#  4.0,
#  3.75,
#  4.5,
#  4.5,
#  4.25,
#  6.0,
#  3.75,
#  4.25,
#  4.0,
#  3.75,
#  3.75,
#  4.75,
#  5.0,
#  3.75,
#  3.75,
#  3.75,
#  5.0,
#  4.25,
#  3.75,
#  4.0,
#  4.25,
#  4.5,
#  3.75,
#  4.0,
#  3.75,
#  5.0,
#  3.75,
#  4.0,
#  3.75,
#  3.75,
#  4.25,
#  4.0,
#  4.25,
#  4.25,
#  4.5,
#  3.75,
#  4.0,
#  3.75,
#  5.0,
#  3.75,
#  0.5,
#  4.0,
#  5.0,
#  5.0,
#  4.5,
#  5.5,
#  4.25,
#  4.0,
#  4.5,
#  3.75,
#  3.75,
#  4.5,
#  3.75,
#  5.5,
#  4.25,
#  5.5,
#  0.0,
#  5.25,
#  4.25,
#  4.0,
#  4.5,
#  3.75,
#  3.75,
#  3.75,
#  3.75,
#  4.25,
#  4.5,
#  4.75,
#  3.75,
#  3.75,
#  3.75,
#  3.75,
#  3.75,
#  4.5,
#  4.25,
#  4.0,
#  4.75,
#  4.75,
#  3.75,
#  4.5,
#  4.0,
#  3.75,
#  3.75,
#  4.0,
#  4.0,
#  3.75,
#  4.75,
#  4.5,
#  3.75,
#  6.75,
#  6.0,
#  4.5,
#  5.5,
# ...

# %%
housing_data['No of Bathrooms']= housing_data['No of Bathrooms'].clip(lower = lower_bound,upper= upper_bound) #clipping data using IQR

# %%
plt.boxplot(housing_data['No of Bathrooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef8cf044440>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef8cf046e70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef8cf32b5c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef8cf0444d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef8cf0444a0>],
#  'means': []}

# %%
#handling outlier in overall grade
skewness = housing_data['Overall Grade'].skew
skewness()
# Out:
# np.float64(0.32149015010896737)

# %%
q1 = np.quantile(housing_data['Overall Grade'],0.25)
q3 = np.quantile(housing_data['Overall Grade'],0.75)
iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 9.5
# 5.5
# 1.0

# %%
OverallGrade_outliers = []
for i in housing_data['No of Bathrooms']:
  if i > upper_bound or i < lower_bound:
    OverallGrade_outliers.append(i)
OverallGrade_outliers
# Out:
# [1.0,
#  2.25,
#  1.0,
#  3.0,
#  2.0,
#  3.625,
#  2.25,
#  1.5,
#  1.0,
#  2.5,
#  2.5,
#  1.0,
#  1.0,
#  1.75,
#  2.0,
#  3.0,
#  2.0,
#  1.0,
#  1.0,
#  1.0,
#  1.75,
#  2.75,
#  2.5,
#  1.5,
#  2.25,
#  2.0,
#  1.75,
#  1.0,
#  1.75,
#  2.5,
#  2.5,
#  1.5,
#  1.75,
#  1.0,
#  2.75,
#  2.5,
#  1.0,
#  2.0,
#  1.0,
#  2.5,
#  2.5,
#  2.25,
#  2.75,
#  1.0,
#  1.0,
#  2.5,
#  1.0,
#  2.5,
#  1.75,
#  2.5,
#  1.0,
#  2.5,
#  1.75,
#  1.75,
#  2.25,
#  2.5,
#  2.5,
#  2.5,
#  3.25,
#  3.0,
#  2.25,
#  1.75,
#  1.75,
#  1.75,
#  2.25,
#  2.75,
#  2.5,
#  2.5,
#  1.0,
#  2.25,
#  3.25,
#  2.0,
#  2.0,
#  2.5,
#  1.75,
#  3.625,
#  1.75,
#  1.0,
#  1.0,
#  2.5,
#  2.5,
#  2.5,
#  1.0,
#  1.5,
#  1.0,
#  1.5,
#  2.25,
#  3.25,
#  2.25,
#  1.75,
#  2.75,
#  1.0,
#  1.5,
#  1.5,
#  2.5,
#  1.75,
#  1.5,
#  1.75,
#  2.5,
#  2.5,
#  2.0,
#  2.25,
#  2.5,
#  1.0,
#  2.5,
#  1.0,
#  1.75,
#  2.5,
#  1.75,
#  2.5,
#  1.75,
#  1.75,
#  1.75,
#  2.5,
#  3.5,
#  3.5,
#  1.0,
#  2.0,
#  1.0,
# ...

# %%
housing_data['Overall Grade']= housing_data['Overall Grade'].clip(lower = lower_bound,upper= upper_bound)

# %%
plt.boxplot(housing_data['Overall Grade'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef8cf9f4ef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef8cf9f6b10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef8cf9f4140>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef8cf9f6240>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef8cf9f7a40>],
#  'means': []}

# %%
#handling outlier in the Living Area after Renovation
skewness=housing_data['Living Area after Renovation (in Sqft)'].skew
skewness()
# Out:
# np.float64(1.1081898144777318)

# %%
#data is highly skewed so apply log transformation
#housing_data['Living Area after Renovation (in Sqft)']=np.log(housing_data['Living Area after Renovation (in Sqft)'])

# %%
from scipy.stats.mstats import winsorize

# Calculate the winsorized values (capping at 5% from both ends)
housing_data['Living Area after Renovation (in Sqft)'] = winsorize(housing_data['Living Area after Renovation (in Sqft)'], limits=[0.05, 0.05])

# Check the skewness after winsorizing
skewness = housing_data['Living Area after Renovation (in Sqft)'].skew()
print(f"Skewness after winsorizing: {skewness}")

# Plot a boxplot to visualize the effect of winsorizing
plt.boxplot(housing_data['Living Area after Renovation (in Sqft)'])
plt.title('Living Area after Renovation (in Sqft) after Winsorizing')
plt.show()
# Out:
# Skewness after winsorizing: 0.6551260572778702

# %%
#handling outlier in
skewness=housing_data['Lot Area after Renovation (in Sqft)'].skew
skewness()
# Out:
# np.float64(9.50550917497705)

# %%
housing_data['Lot Area after Renovation (in Sqft)']=np.log(housing_data['Lot Area after Renovation (in Sqft)'])

# %%
skewness=housing_data['Lot Area after Renovation (in Sqft)'].skew
skewness()
# Out:
# np.float64(0.9667678129338569)

# %%
housing_data['Lot Area after Renovation (in Sqft)']=winsorize(housing_data['Lot Area after Renovation (in Sqft)'],limits=(.05,.15))

# %%
plt.boxplot(housing_data['Lot Area after Renovation (in Sqft)'])
plt.title('Lot Area after Renovation (in Sqft) after Winsorizing')
plt.show()

# %% [markdown]
# ##encoding
# converting categorical into numerical data

# %%
categorical_data
# Out:
#       Date House was Sold Waterfront View No of Times Visited  \
# 0         14 October 2017              No                 NaN
# 1        14 December 2017              No                 NaN
# 2        15 February 2016              No                 NaN
# 3        14 December 2017              No                 NaN
# 4        15 February 2016              No                 NaN
# ...                   ...             ...                 ...
# 21608         14 May 2017              No                 NaN
# 21609    15 February 2016              No                 NaN
# 21610        14 June 2017              No                 NaN
# 21611     15 January 2016              No                 NaN
# 21612     14 October 2017              No                 NaN
#
#       Condition of the House
# 0                       Fair
# 1                       Fair
# 2                       Fair
# 3                  Excellent
# 4                       Fair
# ...                      ...
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder

# %%
#ordinal encoding
ordinal_enc=OrdinalEncoder(categories=[['Bad','Okay','Fair','Good','Excellent']])
housing_data['Condition of the House']=ordinal_enc.fit_transform(housing_data[['Condition of the House']])
housing_data
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  No of Floors  \
# 0       12.309982             3.0             1.00           1.0
# 1       13.195614             3.0             2.25           2.0
# 2       12.100712             2.0             1.00           1.0
# 3       13.311329             4.0             3.00           1.0
# 4       13.142166             3.0             2.00           1.0
# ...           ...             ...              ...           ...
# 21608   12.793859             3.0             2.50           3.0
# 21609   12.899220             4.0             2.50           2.0
# 21610   12.904459             2.0             0.75           2.0
# 21611   12.899220             3.0             2.50           2.0
# 21612   12.691580             2.0             0.75           2.0
#
#       Waterfront View  Condition of the House  Overall Grade  \
# 0                  No                     2.0            7.0
# ...

# %%
#label encoding
label_enc=LabelEncoder()

housing_data['Waterfront View']=label_enc.fit_transform(housing_data['Waterfront View'])
housing_data
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  No of Floors  \
# 0       12.309982             3.0             1.00           1.0
# 1       13.195614             3.0             2.25           2.0
# 2       12.100712             2.0             1.00           1.0
# 3       13.311329             4.0             3.00           1.0
# 4       13.142166             3.0             2.00           1.0
# ...           ...             ...              ...           ...
# 21608   12.793859             3.0             2.50           3.0
# 21609   12.899220             4.0             2.50           2.0
# 21610   12.904459             2.0             0.75           2.0
# 21611   12.899220             3.0             2.50           2.0
# 21612   12.691580             2.0             0.75           2.0
#
#        Waterfront View  Condition of the House  Overall Grade  \
# 0                    0                     2.0            7.0
# ...

# %%
correlation_waterfront_sale_price = housing_data['Sale Price'].corr(housing_data['Waterfront View'])
correlation_waterfront_sale_price
# Out:
# np.float64(0.1746057076842869)

# %%
correlation_zipcode_price =housing_data['Sale Price'].corr(housing_data['Zipcode'])
correlation_zipcode_price
# Out:
# np.float64(-0.038368552484517204)

# %%
housing_data =housing_data.drop(['Waterfront View','Zipcode'],axis=1)

# %%
housing_data
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  No of Floors  \
# 0       12.309982             3.0             1.00           1.0
# 1       13.195614             3.0             2.25           2.0
# 2       12.100712             2.0             1.00           1.0
# 3       13.311329             4.0             3.00           1.0
# 4       13.142166             3.0             2.00           1.0
# ...           ...             ...              ...           ...
# 21608   12.793859             3.0             2.50           3.0
# 21609   12.899220             4.0             2.50           2.0
# 21610   12.904459             2.0             0.75           2.0
# 21611   12.899220             3.0             2.50           2.0
# 21612   12.691580             2.0             0.75           2.0
#
#        Condition of the House  Overall Grade  Age of House (in Years)  \
# 0                         2.0            7.0                       63
# ...

# %% [markdown]
# ##scaling

# %%
skewness=housing_data['Age of House (in Years)'].skew
skewness()
# Out:
# np.float64(0.469543850610496)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
minmax_scale =MinMaxScaler()
std_scale =StandardScaler()

# %%
housing_data['Age of House (in Years)']=minmax_scale.fit_transform(housing_data[['Age of House (in Years)']])

# %%
housing_data
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  No of Floors  \
# 0       12.309982             3.0             1.00           1.0
# 1       13.195614             3.0             2.25           2.0
# 2       12.100712             2.0             1.00           1.0
# 3       13.311329             4.0             3.00           1.0
# 4       13.142166             3.0             2.00           1.0
# ...           ...             ...              ...           ...
# 21608   12.793859             3.0             2.50           3.0
# 21609   12.899220             4.0             2.50           2.0
# 21610   12.904459             2.0             0.75           2.0
# 21611   12.899220             3.0             2.50           2.0
# 21612   12.691580             2.0             0.75           2.0
#
#        Condition of the House  Overall Grade  Age of House (in Years)  \
# 0                         2.0            7.0                 0.521739
# ...

# %%
housing_data['No of Bathrooms']=housing_data['No of Bathrooms'].astype('int64')

# %%
housing_data
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  No of Floors  \
# 0       12.309982             3.0                1           1.0
# 1       13.195614             3.0                2           2.0
# 2       12.100712             2.0                1           1.0
# 3       13.311329             4.0                3           1.0
# 4       13.142166             3.0                2           1.0
# ...           ...             ...              ...           ...
# 21608   12.793859             3.0                2           3.0
# 21609   12.899220             4.0                2           2.0
# 21610   12.904459             2.0                0           2.0
# 21611   12.899220             3.0                2           2.0
# 21612   12.691580             2.0                0           2.0
#
#        Condition of the House  Overall Grade  Age of House (in Years)  \
# 0                         2.0            7.0                 0.521739
# ...

# %%
skewness=housing_data['Living Area after Renovation (in Sqft)'].skew
skewness()
# Out:
# np.float64(0.6551260572778702)

# %%
housing_data['Living Area after Renovation (in Sqft)']=minmax_scale.fit_transform(housing_data[['Living Area after Renovation (in Sqft)']])

# %%
skewness=housing_data['Lot Area after Renovation (in Sqft)'].skew
skewness()
# Out:
# np.float64(-0.7935473401483912)

# %%
housing_data['Lot Area after Renovation (in Sqft)']=minmax_scale.fit_transform(housing_data[['Lot Area after Renovation (in Sqft)']])

# %%
sns.histplot(housing_data['Sale Price'],kde=True)
# Out:
# <Axes: xlabel='Sale Price', ylabel='Count'>

# %%
skewness=housing_data['Sale Price'].skew
skewness()
# Out:
# np.float64(0.4290013346856479)

# %%
housing_data['Sale Price']=minmax_scale.fit_transform(housing_data[['Sale Price']])

# %%
corr_df=housing_data.corr
corr_df()
# Out:
#                                         Sale Price  No of Bedrooms  \
# Sale Price                                1.000000        0.355695
# No of Bedrooms                            0.355695        1.000000
# No of Bathrooms                           0.490807        0.470908
# No of Floors                              0.310754        0.184616
# Condition of the House                    0.039524        0.024704
# Overall Grade                             0.673595        0.373130
# Age of House (in Years)                  -0.080775       -0.170424
# Living Area after Renovation (in Sqft)    0.608246        0.422053
# Lot Area after Renovation (in Sqft)       0.076436        0.224696
#
#                                         No of Bathrooms  No of Floors  \
# Sale Price                                     0.490807      0.310754
# No of Bedrooms                                 0.470908      0.184616
# No of Bathrooms                                1.000000      0.489764
# ...

# %% [markdown]
# ###Train-Test Split

# %%
#vertical split
y=housing_data['Sale Price']
x=housing_data.drop(columns='Sale Price')

# %%
y
# Out:
# 0        0.234210
# 1        0.425429
# 2        0.189025
# 3        0.450414
# 4        0.413889
#            ...
# 21608    0.338685
# 21609    0.361434
# 21610    0.362565
# 21611    0.361434
# 21612    0.316602
# Name: Sale Price, Length: 21607, dtype: float64

# %%
x
# Out:
#        No of Bedrooms  No of Bathrooms  No of Floors  Condition of the House  \
# 0                 3.0                1           1.0                     2.0
# 1                 3.0                2           2.0                     2.0
# 2                 2.0                1           1.0                     2.0
# 3                 4.0                3           1.0                     4.0
# 4                 3.0                2           1.0                     2.0
# ...               ...              ...           ...                     ...
# 21608             3.0                2           3.0                     2.0
# 21609             4.0                2           2.0                     2.0
# 21610             2.0                0           2.0                     2.0
# 21611             3.0                2           2.0                     2.0
# 21612             2.0                0           2.0                     2.0
#
# ...

# %%
#horizontal split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=42)

# %%
x_test.shape
# Out:
# (4322, 8)

# %%
x_train.shape
# Out:
# (17285, 8)

# %%
y_test.shape
# Out:
# (4322,)

# %%
y_train.shape
# Out:
# (17285,)
